# %%
import os
import subprocess

# %%
output = subprocess.check_output("python -m fitsnap3 Ta-example.in", shell=True, universal_newlines=True)
output.split("\n")
# Out:
# ['',
#  '    ______ _  __  _____  _   __ ___     ____  ',
#  '   / ____/(_)/ /_/ ___/ / | / //   |   / __ \\ ',
#  '  / /_   / // __/\\__ \\ /  |/ // /| |  / /_/ /',
#  ' / __/  / // /_ ___/ // /|  // ___ | / ____/ ',
#  '/_/    /_/ \\__//____//_/ |_//_/  |_|/_/      ',
#  '',
#  '-----------',
#  'Reading input...',
#  'Finished reading input',
#  'mpi4py version:  3.0.3',
#  'numpy version:  1.19.4',
#  'scipy version:  1.5.3',
#  'pandas version:  1.1.4',
#  '-----------',
#  'Displaced_A15 : Detected  9  fitting on  9  testing on  0',
#  'Displaced_BCC : Detected  9  fitting on  9  testing on  0',
#  'Displaced_FCC : Detected  9  fitting on  9  testing on  0',
#  'Elastic_BCC : Detected  100  fitting on  100  testing on  0',
#  'Elastic_FCC : Detected  100  fitting on  100  testing on  0',
#  'GSF_110 : Detected  22  fitting on  22  testing on  0',
#  'GSF_112 : Detected  22  fitting on  22  testing on  0',
#  'Liquid : Detected  3  fitting on  3  testing on  0',
# ...

# %%
# !cat Ta_metrics.csv
# Out:
# Group,Weighting,Subsystem,ncount,mae,rmae,rmse,rrmse,ssr,rsq
# *ALL,Unweighted,Combined,15213,9783.895073836185,0.10063082641554882,144442.16313224158,0.22781595058908022,317397011053254.7,0.9480998926571937
# *ALL,Unweighted,Energy,363,0.11278674722618152,0.05998439707767943,0.3797693452675669,0.07621908206223421,52.35358628459918,0.9941906515295904
# *ALL,Unweighted,Force,12672,0.07575757670459775,0.13482546441527266,0.16097300621585758,0.12039852100056145,328.36077622872085,0.9855041961408774
# *ALL,Unweighted,Stress,2178,68338.56511325465,0.10073255198660483,381744.2274776692,0.24572929430717017,317397011052873.94,0.9396171139193001
# *ALL,Weighted,Combined,15213,0.06999218345036956,0.0055213697380578864,0.17488598289234855,0.0011096599392611084,465.291232976946,0.9999987686548192
# *ALL,Weighted,Energy,363,0.2608423012277452,0.0006254553272436001,0.6132321258187711,0.0006603301754830115,136.50747136944386,0.9999995639640593
# ...

# %%
# !cat Ta_pot.snapcoeff
# Out:
# # fitsnap fit generated on 2020-11-29 16:28:27.480675
#
# 1 31
# Ta 0.5 1.0
#  -2.97994848705230186           #  B[0]
#  -0.0114374539722842811         #  B[1, 0, 0, 0]
#  -0.00765461855113528863        #  B[2, 1, 0, 1]
#  -0.050261683746312312          #  B[3, 1, 1, 2]
#  -0.14991750306856988           #  B[4, 2, 0, 2]
#  0.0946827935902723739          #  B[5, 2, 1, 3]
#  0.058262775548022061           #  B[6, 2, 2, 2]
#  0.0606076096845144796          #  B[7, 2, 2, 4]
#  -0.115443486307961751          #  B[8, 3, 0, 3]
#  -0.170155722689116246          #  B[9, 3, 1, 4]
#  -0.105692176533227655          #  B[10, 3, 2, 3]
#  0.0397826631070548747          #  B[11, 3, 2, 5]
#  -0.113740487868262657          #  B[12, 3, 3, 4]
#  0.040487649681044173           #  B[13, 3, 3, 6]
#  -0.0726629412536456964         #  B[14, 4, 0, 4]
#  -0.0648706052876552031         #  B[15, 4, 1, 5]
#  -0.0953306396015494301         #  B[16, 4, 2, 4]
#  -0.102394326002812078          #  B[17, 4, 2, 6]
# ...

# %%
# !cat Ta_pot.snapparam
# Out:
#     # required
#     rcutfac 4.67637
#     twojmax 6
#
#     #  optional
#     rfac0 0.99363
#     rmin0 0.0
#     bzeroflag 0
#     quadraticflag 0
#     wselfallflag 0
#     chemflag 0
#     bnormflag 0

# %%
for f in ["Ta_metrics.csv", "Ta_pot.snapcoeff", "Ta_pot.snapparam"]:
    os.remove(f)
